# %% [markdown]
# ## 0. Dependencies

# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\santhosh d\appdata\roaming\python\python39\site-packages (0.9.0)
# Requirement already satisfied: opencv-python in c:\users\anaconda\lib\site-packages (4.6.0.66)
# Requirement already satisfied: pandas in c:\users\anaconda\lib\site-packages (1.4.2)
# Requirement already satisfied: scikit-learn in c:\users\anaconda\lib\site-packages (1.1.2)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\anaconda\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\anaconda\lib\site-packages (from mediapipe) (3.19.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\santhosh d\appdata\roaming\python\python39\site-packages (from mediapipe) (22.11.23)
# Requirement already satisfied: opencv-contrib-python in c:\users\santhosh d\appdata\roaming\python\python39\site-packages (from mediapipe) (4.6.0.66)
# Requirement already satisfied: numpy in c:\users\anaconda\lib\site-packages (from mediapipe) (1.21.5)
# Requirement already satisfied: absl-py in c:\users\santhosh d\appdata\roaming\python\python39\site-packages (from mediapipe) (1.3.0)
# Requirement already satisfied: matplotlib in c:\users\anaconda\lib\site-packages (from mediapipe) (3.5.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anaconda\lib\site-packages (from pandas) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\anaconda\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\anaconda\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\anaconda\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\anaconda\lib\site-packages (from scikit-learn) (1.7.3)
# Requirement already satisfied: six>=1.5 in c:\users\anaconda\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\anaconda\lib\site-packages (from matplotlib->mediapipe) (9.0.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\anaconda\lib\site-packages (from matplotlib->mediapipe) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\anaconda\lib\site-packages (from matplotlib->mediapipe) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\anaconda\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\anaconda\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\anaconda\lib\site-packages (from matplotlib->mediapipe) (21.3)

# %%
import mediapipe as mp
import cv2
import numpy as np
import time
import pandas as pd
import csv
import os
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score , precision_score , recall_score
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression , RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
import pickle

# %%
print('\n'.join(f'{m.__name__}=={m.__version__}' for m in globals().values() if getattr(m, '__version__', None)))
# Out:
# mediapipe==0.9.0
# cv2==4.6.0
# numpy==1.21.5
# pandas==1.4.2
# csv==1.0

# %%
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %% [markdown]
# ## 1. Detections

# %%
cap = cv2.VideoCapture('v1.mp4',apiPreference=cv2.CAP_MSMF)

# model initiation
with mp_pose.Pose(min_detection_confidence=0.5,min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, image = cap.read()
        
        # Feed color conversion
        image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        # pose detections
        results = pose.process(image)
        
        # revert back to bgr for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
        
        mp_drawing.draw_landmarks(image,results.pose_landmarks, mp_pose.POSE_CONNECTIONS
                                  ,mp_drawing.DrawingSpec(color=(245,117,66),
                                                          thickness=2, circle_radius=4)
                                  ,mp_drawing.DrawingSpec(color=(245,66,230),
                                                          thickness=2,circle_radius=2))
        cv2.imshow('Raw Feed',image)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
            
    cap.release()
    cv2.destroyAllWindows()

# %% [markdown]
# ## 1.1 Video for Training

# %%
cap =cv2.VideoCapture('v4.mp4')

height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
fps = cap.get(cv2.CAP_PROP_FPS)
vwriter = cv2.VideoWriter('ded1.mp4',cv2.VideoWriter_fourcc('P','I','M','1'), 
                          fps, (int(width), int(height)))
time.sleep(5)
while cap.isOpened():
    ret,frame = cap.read()
    
    try: 
        cv2.imshow("Training Video",frame)
        vwriter.write(frame)
    except Exception as e:
        break
        
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
vwriter.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 2. Extracting coordinates

# %%
import csv
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
landmarks = ['class']
for val in range(1,34):
    landmarks += ['x{}'.format(val),'y{}'.format(val),'z{}'.format(val),'v{}'.format(val)]

# %%
landmarks
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 landmarks
#
# NameError: name 'landmarks' is not defined

# %%
with open("coords.csv",mode='w',newline='') as f:
    csv_writer = csv.writer(f,delimiter=',',quotechar='"',quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
def export_landmark(results,action):
    try:
        keypoints = np.array([[res.x,res.y,
                        res.z,res.visibility] for res in results.pose_landmarks.landmark]).flatten().tolist()
        keypoints.insert(0,action)
        
        with open('coords.csv',mode='a',newline='') as f:
            csv_writer = csv.writer(f,delimiter=',',quotechar='"',quoting=csv.QUOTE_MINIMAL)
            csv_writer.writerow(keypoints)
    except Exception as e:
        print(e)

# %%
export_landmark(results,'up')

# %%
results.pose_landmarks.landmark
# Out:
# [x: 0.4719256
# y: 0.051216282
# z: 0.26841727
# visibility: 0.99943215
# , x: 0.4694388
# y: 0.04037122
# z: 0.24188228
# visibility: 0.99932116
# , x: 0.46713042
# y: 0.03904644
# z: 0.24187854
# visibility: 0.99935937
# , x: 0.4650374
# y: 0.037516646
# z: 0.24184926
# visibility: 0.9992734
# , x: 0.47691065
# y: 0.04275387
# z: 0.24318056
# visibility: 0.99929017
# , x: 0.47948736
# y: 0.042950306
# z: 0.24322768
# visibility: 0.99930376
# , x: 0.4823617
# y: 0.04265015
# z: 0.2431539
# visibility: 0.9992277
# , x: 0.46064982
# y: 0.038756765
# z: 0.14295341
# visibility: 0.9995671
# , x: 0.48478436
# y: 0.04461633
# z: 0.14826149
# visibility: 0.9993391
# , x: 0.46831074
# y: 0.05909084
# z: 0.23851559
# visibility: 0.99938154
# , x: 0.4753035
# y: 0.060016777
# z: 0.23995042
# visibility: 0.9992825
# , x: 0.43164387
# y: 0.08094204
# z: 0.0773942
# visibility: 0.99992627
# , x: 0.50681007
# y: 0.08634732
# z: 0.08848335
# visibility: 0.9998875
# , x: 0.41165978
# y: 0.18946266
# z: 0.08470501
# visibility: 0.9450279
# , x: 0.5294405
# y: 0.20453115
# z: 0.0868011
# visibility: 0.92577225
# , x: 0.40325466
# y: 0.29386625
# z: 0.14089951
# visibility: 0.65588605
# , x: 0.53958434
# y: 0.3195245
# z: 0.15525262
# visibility: 0.64030814
# , x: 0.39749473
# y: 0.31906176
# z: 0.14123234
# visibility: 0.5355625
# , x: 0.54323447
# y: 0.34565458
# z: 0.16951855
# visibility: 0.5202142
# , x: 0.40512973
# y: 0.31740648
# z: 0.150297
# visibility: 0.52102363
# , x: 0.5361165
# y: 0.3434789
# z: 0.16966954
# visibility: 0.4987616
# , x: 0.4101417
# y: 0.3089554
# z: 0.14563158
# visibility: 0.47315335
# , x: 0.5324117
# y: 0.33447617
# z: 0.15848407
# visibility: 0.46831957
# , x: 0.45273584
# y: 0.320743
# z: -0.008201465
# visibility: 0.9997061
# , x: 0.49698535
# y: 0.31822613
# z: 0.007950656
# visibility: 0.9994418
# , x: 0.4361554
# y: 0.51533705
# z: -0.03606478
# visibility: 0.95184934
# , x: 0.5116592
# y: 0.5158734
# z: 0.02530145
# visibility: 0.92175406
# , x: 0.41785717
# y: 0.7079613
# z: -0.042601265
# visibility: 0.963589
# , x: 0.52490324
# y: 0.7089942
# z: 0.028868347
# visibility: 0.9377074
# , x: 0.42283964
# y: 0.74658674
# z: -0.04342286
# visibility: 0.93603003
# , x: 0.5237708
# y: 0.74339086
# z: 0.030151403
# visibility: 0.8868728
# , x: 0.3860876
# y: 0.74270606
# z: -0.08335696
# visibility: 0.87041116
# , x: 0.5418862
# y: 0.7359574
# z: -0.0067497455
# visibility: 0.75719416
# ]

# %%
cap = cv2.VideoCapture('v5.mp4',apiPreference=cv2.CAP_MSMF)
#Initiate model
with mp_pose.Pose(min_detection_confidence = 0.5, min_tracking_confidence = 0.5) as pose:
    while cap.isOpened():
        ret,frame = cap.read()
        
        #recolor
        image = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Make Detections
        results = pose.process(image)
        
        #Recolor image back to BGR for rendering
        image.flags.writeable = True
        image = cv2.cvtColor(image,cv2.COLOR_RGB2BGR)
        
        mp_drawing.draw_landmarks(image,results.pose_landmarks, mp_pose.POSE_CONNECTIONS
                                  ,mp_drawing.DrawingSpec(color=(245,117,66),
                                                          thickness=2, circle_radius=4)
                                  ,mp_drawing.DrawingSpec(color=(245,66,230),
                                                          thickness=2,circle_radius=2))
        k = cv2.waitKey(1)
        if k == 117:
            export_landmark(results,'up')
        if k == 100:
            export_landmark(results,'down')
        
        cv2.imshow('Raw Webcam Feed',image)
        
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break;
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# ## 3. Training

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
df = pd.read_csv('coords.csv')

# %%
df
# Out:
#      class        x1        y1        z1        v1        x2        y2  \
# 0       up  0.553414  0.534331 -0.857037  0.999868  0.578112  0.459495
# 1       up  0.298316  0.217357 -0.333526  0.999911  0.307454  0.203464
# 2     down  0.365290  0.439646 -0.628573  0.998388  0.375520  0.415676
# 3       up  0.373031  0.186182 -0.370811  0.999881  0.376678  0.173634
# 4       up  0.370073  0.179774 -0.381279  0.999907  0.373892  0.169214
# ...    ...       ...       ...       ...       ...       ...       ...
# 1615  down  0.505912  0.342064 -0.571615  0.999977  0.509332  0.321204
# 1616  down  0.510507  0.357249 -0.569984  0.999971  0.514529  0.339799
# 1617  down  0.513802  0.361378 -0.480517  0.999970  0.518541  0.344641
# 1618  down  0.515294  0.355196 -0.475967  0.999962  0.520098  0.338118
# 1619  down  0.518305  0.288228 -0.663143  0.999962  0.523724  0.268151
#
#             z2        v2        x3  ...       z31       v31       x32  \
# 0    -0.823187  0.999740  0.594897  ...  0.278216  0.000019  0.582104
# 1    -0.314020  0.999759  0.312366  ...  0.134620  0.305781  0.385195
# 2    -0.624889  0.996742  0.380499  ... -0.030983  0.108412  0.445133
# 3    -0.349738  0.999689  0.380530  ...  0.208197  0.398352  0.423046
# 4    -0.359603  0.999739  0.377747  ...  0.219616  0.381198  0.422675
# ...        ...       ...       ...  ...       ...       ...       ...
# 1615 -0.571421  0.999955  0.512551  ...  0.012669  0.657344  0.597133
# 1616 -0.566404  0.999944  0.517616  ...  0.004810  0.613308  0.582749
# 1617 -0.480635  0.999947  0.521607  ...  0.004908  0.593730  0.571724
# 1618 -0.475914  0.999940  0.523091  ...  0.026334  0.570312  0.577899
# 1619 -0.650662  0.999936  0.526930  ... -0.029152  0.535525  0.568038
#
#            y32       z32       v32       x33       y33       z33       v33
# 0     2.896028 -0.188118  0.000063  0.409083  2.891962 -0.296995  0.000027
# 1     0.937053  0.014909  0.450979  0.270425  0.942263 -0.036056  0.497464
# 2     0.867158 -0.119507  0.190882  0.336602  0.883210 -0.153117  0.176909
# 3     0.905484  0.164315  0.514231  0.340754  0.935973  0.039783  0.591700
# 4     0.910563  0.145387  0.493635  0.344373  0.935439  0.055919  0.569865
# ...        ...       ...       ...       ...       ...       ...       ...
# 1615  0.765527 -0.058824  0.737504  0.402833  0.790975 -0.090179  0.792935
# 1616  0.768927 -0.094313  0.688998  0.402705  0.790554 -0.100184  0.749907
# 1617  0.755795 -0.062082  0.660315  0.402678  0.789983 -0.098454  0.739275
# 1618  0.758054 -0.021524  0.624968  0.403091  0.786997 -0.071798  0.724207
# 1619  0.760343 -0.161118  0.606097  0.402848  0.787060 -0.160763  0.684526
#
# [1620 rows x 133 columns]

# %%
x = df.drop('class',axis = 1)
y = df['class']

# %%
x
# Out:
#             x1        y1        z1        v1        x2        y2        z2  \
# 0     0.553414  0.534331 -0.857037  0.999868  0.578112  0.459495 -0.823187
# 1     0.298316  0.217357 -0.333526  0.999911  0.307454  0.203464 -0.314020
# 2     0.365290  0.439646 -0.628573  0.998388  0.375520  0.415676 -0.624889
# 3     0.373031  0.186182 -0.370811  0.999881  0.376678  0.173634 -0.349738
# 4     0.370073  0.179774 -0.381279  0.999907  0.373892  0.169214 -0.359603
# ...        ...       ...       ...       ...       ...       ...       ...
# 1615  0.505912  0.342064 -0.571615  0.999977  0.509332  0.321204 -0.571421
# 1616  0.510507  0.357249 -0.569984  0.999971  0.514529  0.339799 -0.566404
# 1617  0.513802  0.361378 -0.480517  0.999970  0.518541  0.344641 -0.480635
# 1618  0.515294  0.355196 -0.475967  0.999962  0.520098  0.338118 -0.475914
# 1619  0.518305  0.288228 -0.663143  0.999962  0.523724  0.268151 -0.650662
#
#             v2        x3        y3  ...       z31       v31       x32  \
# 0     0.999740  0.594897  0.458089  ...  0.278216  0.000019  0.582104
# 1     0.999759  0.312366  0.203748  ...  0.134620  0.305781  0.385195
# 2     0.996742  0.380499  0.413431  ... -0.030983  0.108412  0.445133
# 3     0.999689  0.380530  0.173480  ...  0.208197  0.398352  0.423046
# 4     0.999739  0.377747  0.169542  ...  0.219616  0.381198  0.422675
# ...        ...       ...       ...  ...       ...       ...       ...
# 1615  0.999955  0.512551  0.317854  ...  0.012669  0.657344  0.597133
# 1616  0.999944  0.517616  0.336640  ...  0.004810  0.613308  0.582749
# 1617  0.999947  0.521607  0.341343  ...  0.004908  0.593730  0.571724
# 1618  0.999940  0.523091  0.335115  ...  0.026334  0.570312  0.577899
# 1619  0.999936  0.526930  0.266181  ... -0.029152  0.535525  0.568038
#
#            y32       z32       v32       x33       y33       z33       v33
# 0     2.896028 -0.188118  0.000063  0.409083  2.891962 -0.296995  0.000027
# 1     0.937053  0.014909  0.450979  0.270425  0.942263 -0.036056  0.497464
# 2     0.867158 -0.119507  0.190882  0.336602  0.883210 -0.153117  0.176909
# 3     0.905484  0.164315  0.514231  0.340754  0.935973  0.039783  0.591700
# 4     0.910563  0.145387  0.493635  0.344373  0.935439  0.055919  0.569865
# ...        ...       ...       ...       ...       ...       ...       ...
# 1615  0.765527 -0.058824  0.737504  0.402833  0.790975 -0.090179  0.792935
# 1616  0.768927 -0.094313  0.688998  0.402705  0.790554 -0.100184  0.749907
# 1617  0.755795 -0.062082  0.660315  0.402678  0.789983 -0.098454  0.739275
# 1618  0.758054 -0.021524  0.624968  0.403091  0.786997 -0.071798  0.724207
# 1619  0.760343 -0.161118  0.606097  0.402848  0.787060 -0.160763  0.684526
#
# [1620 rows x 132 columns]

# %%
y
# Out:
# 0         up
# 1         up
# 2       down
# 3         up
# 4         up
#         ...
# 1615    down
# 1616    down
# 1617    down
# 1618    down
# 1619    down
# Name: class, Length: 1620, dtype: object

# %%
x_train , x_test, y_train, y_test = train_test_split(x,y,test_size = 0.3,random_state = 1234)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression , RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
fit_model = {}
for algo , pipeline in pipelines.items():
    model = pipeline.fit(x_train,y_train)
    fit_model[algo] = model

# %%
fit_model['rc'].predict(x_test)
# Out:
# array(['down', 'up', 'down', 'up', 'down', 'down', 'down', 'down', 'up',
#        'up', 'down', 'down', 'up', 'down', 'down', 'up', 'down', 'down',
#        'up', 'down', 'up', 'down', 'down', 'up', 'up', 'down', 'up',
#        'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'down',
#        'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'down',
#        'up', 'down', 'up', 'up', 'down', 'down', 'down', 'down', 'down',
#        'up', 'down', 'up', 'down', 'up', 'down', 'up', 'up', 'up', 'up',
#        'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'up',
#        'down', 'down', 'up', 'down', 'down', 'up', 'down', 'up', 'down',
#        'up', 'up', 'down', 'up', 'up', 'down', 'up', 'down', 'up', 'up',
#        'down', 'up', 'down', 'up', 'down', 'up', 'up', 'down', 'down',
#        'up', 'down', 'up', 'down', 'up', 'down', 'up', 'up', 'up', 'down',
#        'up', 'down', 'down', 'up', 'down', 'down', 'down', 'up', 'down',
#        'down', 'up', 'up', 'down', 'down', 'up', 'down', 'up', 'down',
#        'down', 'up', 'up', 'up', 'down', 'down', 'up', 'up', 'up', 'up',
#        'down', 'down', 'down', 'up', 'down', 'up', 'down', 'up', 'up',
#        'up', 'down', 'up', 'up', 'down', 'up', 'up', 'up', 'down', 'down',
#        'up', 'up', 'down', 'up', 'down', 'down', 'down', 'down', 'up',
#        'up', 'down', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'up',
#        'up', 'up', 'down', 'down', 'up', 'down', 'up', 'up', 'down', 'up',
#        'up', 'up', 'up', 'down', 'up', 'up', 'up', 'up', 'down', 'up',
#        'down', 'up', 'down', 'up', 'down', 'down', 'up', 'up', 'down',
#        'up', 'up', 'up', 'up', 'down', 'up', 'down', 'up', 'down', 'down',
#        'up', 'up', 'up', 'down', 'up', 'down', 'down', 'down', 'up',
#        'down', 'up', 'up', 'down', 'down', 'up', 'up', 'up', 'up', 'up',
#        'up', 'down', 'down', 'up', 'down', 'up', 'down', 'down', 'up',
#        'up', 'down', 'down', 'up', 'down', 'up', 'up', 'down', 'up',
#        'down', 'up', 'up', 'up', 'up', 'down', 'down', 'up', 'down', 'up',
#        'down', 'up', 'down', 'down', 'down', 'down', 'down', 'up', 'down',
#        'down', 'up', 'down', 'up', 'down', 'up', 'down', 'down', 'up',
#        'up', 'down', 'up', 'down', 'down', 'up', 'up', 'up', 'down',
#        'down', 'up', 'up', 'up', 'down', 'up', 'up', 'up', 'down', 'down',
#        'down', 'down', 'up', 'up', 'down', 'up', 'up', 'up', 'down', 'up',
#        'down', 'up', 'down', 'down', 'up', 'down', 'up', 'down', 'down',
#        'down', 'down', 'down', 'up', 'down', 'down', 'down', 'down',
#        'down', 'down', 'up', 'down', 'down', 'up', 'up', 'up', 'down',
#        'up', 'down', 'up', 'down', 'up', 'up', 'up', 'up', 'up', 'down',
#        'up', 'up', 'down', 'up', 'up', 'down', 'up', 'down', 'up', 'up',
#        'down', 'up', 'up', 'down', 'down', 'up', 'up', 'down', 'up',
#        'down', 'down', 'up', 'up', 'up', 'down', 'up', 'down', 'up', 'up',
#        'down', 'up', 'up', 'up', 'down', 'down', 'up', 'up', 'up', 'up',
#        'up', 'up', 'up', 'down', 'down', 'down', 'up', 'down', 'down',
#        'up', 'up', 'down', 'down', 'up', 'down', 'up', 'up', 'down', 'up',
#        'up', 'down', 'down', 'up', 'down', 'up', 'up', 'up', 'down', 'up',
#        'up', 'up', 'up', 'down', 'up', 'down', 'up', 'down', 'up', 'up',
#        'up', 'down', 'down', 'up', 'down', 'down', 'up', 'up', 'down',
#        'up', 'up', 'up', 'down', 'up', 'down', 'up', 'up', 'down', 'up',
#        'down', 'down', 'up', 'up', 'up', 'down', 'down', 'down', 'down',
#        'up', 'down', 'down', 'up', 'down', 'down', 'up', 'up', 'up', 'up',
#        'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'down',
#        'up', 'down', 'up', 'down', 'up', 'down', 'up', 'up', 'down',
#        'down', 'up', 'down'], dtype='<U4')

# %%
y_test.head(10)
# Out:
# 1595    down
# 1147      up
# 414     down
# 1251      up
# 218     down
# 1568    down
# 831     down
# 1086    down
# 972       up
# 643       up
# Name: class, dtype: object

# %% [markdown]
# ## 4. Evaluation

# %%
from sklearn.metrics import accuracy_score , precision_score , recall_score
import pickle

# %%
for algo,model in fit_model.items():
    yhat = model.predict(x_test)
    print(algo,accuracy_score(y_test.values,yhat),
         precision_score(y_test.values,yhat,average = "binary",pos_label = "up"),
         recall_score(y_test.values,yhat,average = "binary",pos_label = "up"))
# Out:
# lr 0.9917695473251029 0.9884615384615385 0.9961240310077519
# rc 0.9917695473251029 0.9847328244274809 1.0
# rf 0.9917695473251029 0.9884615384615385 0.9961240310077519
# gb 0.9876543209876543 0.9846153846153847 0.9922480620155039

# %%
yhat = fit_model['rf'].predict(x_test)
yhat[:10]
# Out:
# array(['down', 'down', 'up', 'down', 'down', 'down', 'up', 'up', 'up',
#        'up'], dtype=object)

# %% [markdown]
# ## 5. Save/Load Model using pickle

# %%
with open('model.pkl','wb') as f:
    pickle.dump(fit_model['rf'],f)

# %%
with open('model.pkl','rb') as f:
    model = pickle.load(f)

# %%
model.predict(x_test)
# Out:
# array(['down', 'up', 'down', 'up', 'down', 'down', 'down', 'down', 'up',
#        'up', 'down', 'down', 'up', 'down', 'down', 'up', 'down', 'down',
#        'up', 'down', 'up', 'down', 'down', 'up', 'up', 'down', 'up',
#        'down', 'down', 'down', 'down', 'down', 'up', 'up', 'up', 'down',
#        'down', 'down', 'down', 'up', 'up', 'up', 'up', 'up', 'up', 'down',
#        'up', 'down', 'up', 'up', 'down', 'down', 'down', 'down', 'down',
#        'up', 'down', 'up', 'down', 'up', 'down', 'up', 'up', 'up', 'up',
#        'up', 'up', 'up', 'up', 'up', 'up', 'up', 'up', 'down', 'up',
#        'down', 'down', 'up', 'down', 'down', 'up', 'down', 'up', 'down',
#        'up', 'up', 'down', 'up', 'up', 'down', 'up', 'down', 'up', 'up',
#        'down', 'up', 'down', 'up', 'down', 'up', 'up', 'down', 'down',
#        'up', 'down', 'up', 'down', 'up', 'down', 'up', 'up', 'up', 'down',
#        'up', 'down', 'down', 'up', 'down', 'down', 'down', 'up', 'down',
#        'down', 'up', 'up', 'down', 'down', 'up', 'down', 'up', 'down',
#        'down', 'up', 'up', 'up', 'down', 'down', 'up', 'up', 'up', 'up',
#        'down', 'down', 'down', 'up', 'down', 'up', 'down', 'up', 'up',
#        'up', 'down', 'up', 'up', 'down', 'up', 'up', 'up', 'down', 'down',
#        'up', 'up', 'down', 'up', 'down', 'down', 'down', 'down', 'up',
#        'up', 'down', 'up', 'up', 'up', 'up', 'down', 'down', 'down', 'up',
#        'up', 'up', 'down', 'down', 'up', 'down', 'up', 'up', 'down', 'up',
#        'up', 'up', 'up', 'down', 'up', 'up', 'up', 'up', 'down', 'up',
#        'down', 'up', 'down', 'up', 'down', 'down', 'up', 'up', 'down',
#        'up', 'up', 'up', 'up', 'down', 'up', 'down', 'up', 'down', 'down',
#        'up', 'up', 'up', 'down', 'up', 'down', 'down', 'down', 'up',
#        'down', 'up', 'up', 'down', 'down', 'up', 'up', 'up', 'up', 'up',
#        'up', 'down', 'down', 'up', 'down', 'up', 'down', 'down', 'up',
#        'up', 'down', 'down', 'up', 'down', 'up', 'up', 'down', 'up',
#        'down', 'up', 'up', 'down', 'up', 'down', 'down', 'up', 'down',
#        'up', 'down', 'up', 'down', 'down', 'down', 'down', 'down', 'up',
#        'down', 'down', 'up', 'down', 'up', 'down', 'up', 'down', 'down',
#        'up', 'up', 'down', 'up', 'down', 'down', 'up', 'up', 'up', 'down',
#        'down', 'up', 'up', 'up', 'down', 'up', 'up', 'up', 'down', 'down',
#        'down', 'down', 'up', 'up', 'down', 'up', 'up', 'up', 'down', 'up',
#        'down', 'up', 'down', 'down', 'up', 'down', 'up', 'down', 'down',
#        'down', 'down', 'down', 'up', 'down', 'down', 'down', 'down',
#        'down', 'down', 'up', 'down', 'down', 'up', 'up', 'up', 'down',
#        'up', 'down', 'up', 'down', 'up', 'up', 'up', 'up', 'up', 'down',
#        'up', 'up', 'down', 'up', 'up', 'down', 'up', 'down', 'up', 'up',
#        'down', 'up', 'up', 'down', 'down', 'up', 'up', 'down', 'up',
#        'down', 'down', 'up', 'up', 'up', 'down', 'up', 'down', 'up', 'up',
#        'down', 'up', 'up', 'up', 'down', 'down', 'up', 'up', 'up', 'up',
#        'up', 'up', 'up', 'down', 'down', 'down', 'up', 'down', 'down',
#        'up', 'up', 'down', 'down', 'up', 'down', 'up', 'up', 'down', 'up',
#        'up', 'down', 'down', 'up', 'down', 'up', 'up', 'up', 'down', 'up',
#        'up', 'up', 'up', 'down', 'up', 'down', 'up', 'down', 'up', 'up',
#        'up', 'down', 'down', 'up', 'down', 'down', 'up', 'up', 'down',
#        'up', 'up', 'up', 'down', 'up', 'down', 'up', 'up', 'down', 'up',
#        'down', 'down', 'up', 'up', 'up', 'down', 'down', 'down', 'down',
#        'up', 'down', 'down', 'up', 'down', 'down', 'up', 'up', 'up', 'up',
#        'up', 'up', 'down', 'down', 'down', 'up', 'up', 'up', 'up', 'down',
#        'down', 'down', 'up', 'down', 'up', 'down', 'up', 'up', 'down',
#        'down', 'up', 'down'], dtype=object)
